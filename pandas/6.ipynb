# %%
import pandas as pd
df = pd.read_csv("https://cognitrilha.com.br/datasets/demostrativo_acidentes_eco050.csv.gz")
df2 = pd.read_csv("https://cognitrilha.com.br/datasets/demostrativo_acidentes_eco101.csv.gz")
df3 = pd.read_cvs("https://cognitrilha.com.br/datasets/demostrativo_acidentes_ecosul.csv.gz")
